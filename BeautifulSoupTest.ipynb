# %%
from bs4 import BeautifulSoup
import requests
url='https://sfbay.craigslist.org/search/sss?sort=rel&query=bike rack'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
print(soup)
# Out:
# ﻿<!DOCTYPE html>
#
# <html class="no-js"><head>
# <title>SF bay area for sale "bike rack" - craigslist</title>
# <meta content='SF bay area for sale "bike rack" - craigslist' name="description"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible">
# <link href="https://sfbay.craigslist.org/search/sss" rel="canonical"/>
# <link href="https://sfbay.craigslist.org/search/sss?format=rss&amp;query=bike%20rack&amp;sort=rel" rel="alternate" title='RSS feed for craigslist | SF bay area for sale "bike rack" - craigslist' type="application/rss+xml"/>
# <link href="https://sfbay.craigslist.org/search/sss?s=120&amp;query=bike%20rack&amp;sort=rel" rel="next"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="//www.craigslist.org/styles/cl.css?v=93aa8b9183682fd14ca12ff38c0d801c" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/search.css?v=84cf86bc094026e12fa066bbbab154ac" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/leaflet.css?v=33e3dd14c7deed955c83b6927c5e1f07" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/tocsmaps.css?v=d3ac18e00752d21e15dc93be93a12756" media="all" rel="stylesheet" type="text/css"/>
# <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
# <script type="text/javascript"><!--
# var areaCountry = "US";
# var areaID = "1";
# var areaRegion = "CA";
# var catAbb = "sss";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "grid";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = {"owner":"sso","dealer":"ssq","all":"sss"};
# var searchDistance = null;
# var sectionAbb = "sss";
# var sectionBase = "sss";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# --></script>
# <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=c0739b14a84b052680cdee44fea07435" type="text/javascript" ></script>
#
# <script src="//www.craigslist.org/js/respond-fork.min.js?v=247e877d69233f6f77bff30aca7b5473" type="text/javascript" ></script>
#
# <![endif]-->
# <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=6e47a4bb061d538548771024390aa00b" type="text/javascript" ></script>
#
# <![endif]-->
# </meta></head>
# <body class="search has-map">
# <script type="text/javascript"><!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# --></script>
# <section class="page-container" id="page-top">
# <div class="bglogo"></div>
# <header class="global-header wide">
# <a class="header-logo" href="/" name="logoLink">CL</a>
# <nav class="breadcrumbs-container">
# <form action="/search/sss" class="breadcrumbs-form" data-action="/search/###/sss" id="breadcrumbform" method="get">
# <input name="sort" type="hidden" value="rel"/>
# <input name="query" type="hidden" value="bike rack"/>
# <ul class="breadcrumbs ">
# <li class="crumb area">
# <span class="no-js">
# <a href="/">SF bay area</a>
# </span>
# <select class="js-only" id="areaAbb" name="areaAbb">
# <option value="sfbay">SF bay area</option>
# <option value="bakersfield">bakersfield</option>
# <option value="chico">chico</option>
# <option value="fresno">fresno</option>
# <option value="goldcountry">gold country</option>
# <option value="hanford">hanford</option>
# <option value="mendocino">mendocino co</option>
# <option value="merced">merced</option>
# <option value="modesto">modesto</option>
# <option value="monterey">monterey</option>
# <option value="redding">redding</option>
# <option value="reno">reno</option>
# <option value="sacramento">sacramento</option>
# <option value="slo">san luis obispo</option>
# <option value="santamaria">santa maria</option>
# <option value="stockton">stockton</option>
# <option value="susanville">susanville</option>
# <option value="visalia">visalia-tulare</option>
# <option value="yubasutter">yuba-sutter</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb subarea">
# <select id="subArea" name="subArea">
# <option selected="" value="">all SF bay area</option>
# <option value="eby">east bay</option>
# <option value="nby">north bay</option>
# <option value="pen">peninsula</option>
# <option value="sfc">san francisco</option>
# <option value="scz">santa cruz</option>
# <option value="sby">south bay</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb section">
# <select id="catAbb" name="catAbb">
# <option value="ccc">community</option>
# <option value="eee">events</option>
# <option selected="" value="sss">for sale</option>
# <option value="ggg">gigs</option>
# <option value="hhh">housing</option>
# <option value="jjj">jobs</option>
# <option value="rrr">resumes</option>
# <option value="bbb">services</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb category">
# <select class="js-only" id="subcatAbb">
# <option value="sss">all</option>
# <option value="ata">antiques</option>
# <option value="ppa">appliances</option>
# <option value="ara">arts+crafts</option>
# <option value="sna">atvs/utvs/snow</option>
# <option value="pta">auto parts</option>
# <option value="wta">auto wheels &amp; tires</option>
# <option value="ava">aviation</option>
# <option value="baa">baby+kids</option>
# <option value="bar">barter</option>
# <option value="haa">beauty+hlth</option>
# <option value="bip">bike parts</option>
# <option value="bia">bikes</option>
# <option value="bpa">boat parts</option>
# <option value="boo">boats</option>
# <option value="bka">books</option>
# <option value="bfa">business</option>
# <option value="cta">cars+trucks</option>
# <option value="ema">cds/dvd/vhs</option>
# <option value="moa">cell phones</option>
# <option value="cla">clothes+acc</option>
# <option value="cba">collectibles</option>
# <option value="syp">computer parts</option>
# <option value="sya">computers</option>
# <option value="ela">electronics</option>
# <option value="gra">farm+garden</option>
# <option value="zip">free stuff</option>
# <option value="fua">furniture</option>
# <option value="gms">garage sales</option>
# <option value="foa">general</option>
# <option value="hva">heavy equipment</option>
# <option value="hsa">household</option>
# <option value="jwa">jewelry</option>
# <option value="maa">materials</option>
# <option value="mpa">motorcycle parts</option>
# <option value="mca">motorcycles</option>
# <option value="msa">music instr</option>
# <option value="pha">photo+video</option>
# <option value="rva">RVs</option>
# <option value="sga">sporting</option>
# <option value="tia">tickets</option>
# <option value="tla">tools</option>
# <option value="taa">toys+games</option>
# <option value="tra">trailers</option>
# <option value="vga">video gaming</option>
# <option value="waa">wanted</option>
# </select><span class="no-js">for sale</span>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb no-js">
# <input type="submit" value="go"/>
# </li>
# </ul>
# </form>
# </nav>
# <div class="userlinks">
# <ul class="user-actions">
# <li class="user post">
# <a href="https://post.craigslist.org/c/sfo">post</a>
# </li>
# <li class="user account">
# <a href="https://accounts.craigslist.org/login/home">account</a>
# </li>
# </ul>
# <ul class="user-favs-discards">
# <li class="user">
# <div class="favorites">
# <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>
# </div>
# </li>
# <li class="user discards">
# <form action="/favorites" class="unfavform js-only" method="POST">
# <div class="to-banish-page">
# <input class="lastLink" name="lastLink" type="hidden" value="//sfbay.craigslist.org/search/sss?query=bike%20rack&amp;sort=rel"/>
# <input class="lastTitle" name="lastTitle" type="hidden" value='SF bay area for sale "bike rack" - craigslist'/>
# <input class="unfaves" name="fl" type="hidden"/>
# <input name="uf" type="hidden" value="1"/>
# <a class="to-banish-page-link" href="#">
# <span aria-hidden="true" class="icon icon-trash red"></span>
# <span class="banished_count">0</span>
# <span class="discards-label"> hidden</span>
# </a>
# </div>
# </form>
# </li>
# </ul>
# </div>
# </header>
# <header class="global-header narrow">
# <a class="header-logo" href="/">CL</a>
# <nav class="breadcrumbs-container">
# <ul class="breadcrumbs">
#
#
# SF bay area            &gt;
#
# for sale
#
# </ul>
# </nav>
# <span class="linklike show-wide-header">...</span>
# </header>
# <form action="/search/sss" class="search-form" id="searchform">
# <div class="querybox">
# <div class="form-tab js-only"><span class="search-open" title="hide search">«</span><span class="search-closed" title="show search">»</span></div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search for sale" type="text" value="bike rack"/>
# <button class="searchbtn" type="submit">
# <span aria-hidden="true" class="icon icon-search"></span>
# <span class="screen-reader-text">press to search craigslist</span>
# </button>
# <div class="savealert">
# <a class="saveme" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Fsss%253Fquery%253Dbike%252520rack%2526sort%253Drel" title="save this search">save search</a>
# </div>
# </div>
# <div class="search-options-container">
# <h2 class="search-options-header linklike">
# <div aria-hidden="true" class="icon icon-toggle-gear"></div>
#         options<span class="options-close">close</span>
# </h2>
# <input id="excats" name="excats" type="hidden"/>
# <input name="sort" type="hidden" value="rel"/>
# <div class="search-options">
# <div class="searchgroup categories">
# <div class="cattitle">
# <a class="reset" href="/search/sss" title="clear all search parameters">for sale</a>
# </div>
# <ul class="maincats">
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="bia" id="cat_bia" name="cat_id" type="checkbox" value="68,172"/>
# <a class="category" href="/search/bia?query=bike%20rack&amp;sort=rel">bicycles</a> <span class="count">350</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="bip" id="cat_bip" name="cat_id" type="checkbox" value="197,198"/>
# <a class="category" href="/search/bip?query=bike%20rack&amp;sort=rel">bicycle parts</a> <span class="count">255</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="sga" id="cat_sga" name="cat_id" type="checkbox" value="93,186"/>
# <a class="category" href="/search/sga?query=bike%20rack&amp;sort=rel">sporting goods</a> <span class="count">232</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="mca" id="cat_mca" name="cat_id" type="checkbox" value="69,160"/>
# <a class="category" href="/search/mca?query=bike%20rack&amp;sort=rel">motorcycles/scooters</a> <span class="count">116</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="cta" id="cat_cta" name="cat_id" type="checkbox" value="145,146"/>
# <a class="category" href="/search/cta?query=bike%20rack&amp;sort=rel">cars &amp; trucks</a> <span class="count">111</span>
# </li>
# <li class="morecats js-only closed">
# <span class="linklike closed"><span class="plusminus">+</span>show 40 more</span>
# <span class="linklike open"><span class="plusminus">–</span>hide 40 more</span>
# <span class="count">200</span>
# </li>
# </ul>
# <ul class="othercats closed">
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="pta" id="cat_pta" name="cat_id" type="checkbox" value="122,163"/>
# <a class="category" href="/search/pta?query=bike%20rack&amp;sort=rel">auto parts</a> <span class="count">60</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="foa" id="cat_foa" name="cat_id" type="checkbox" value="5,179"/>
# <a class="category" href="/search/foa?query=bike%20rack&amp;sort=rel">general for sale</a> <span class="count">42</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="rva" id="cat_rva" name="cat_id" type="checkbox" value="124,168"/>
# <a class="category" href="/search/rva?query=bike%20rack&amp;sort=rel">recreational vehicles</a> <span class="count">20</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="tra" id="cat_tra" name="cat_id" type="checkbox" value="205,206"/>
# <a class="category" href="/search/tra?query=bike%20rack&amp;sort=rel">trailers</a> <span class="count">18</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="mpa" id="cat_mpa" name="cat_id" type="checkbox" value="195,196"/>
# <a class="category" href="/search/mpa?query=bike%20rack&amp;sort=rel">motorcycle parts &amp; accessories</a> <span class="count">16</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="baa" id="cat_baa" name="cat_id" type="checkbox" value="107,171"/>
# <a class="category" href="/search/baa?query=bike%20rack&amp;sort=rel">baby &amp; kid stuff</a> <span class="count">9</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="ata" id="cat_ata" name="cat_id" type="checkbox" value="150,169"/>
# <a class="category" href="/search/ata?query=bike%20rack&amp;sort=rel">antiques</a> <span class="count">4</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="bfa" id="cat_bfa" name="cat_id" type="checkbox" value="134,174"/>
# <a class="category" href="/search/bfa?query=bike%20rack&amp;sort=rel">business</a> <span class="count">4</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="fua" id="cat_fua" name="cat_id" type="checkbox" value="141,142"/>
# <a class="category" href="/search/fua?query=bike%20rack&amp;sort=rel">furniture</a> <span class="count">4</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="gms" id="cat_gms" name="cat_id" type="checkbox" value="73"/>
# <a class="category" href="/search/gms?query=bike%20rack&amp;sort=rel">garage &amp; moving sales</a> <span class="count">4</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="sna" id="cat_sna" name="cat_id" type="checkbox" value="191,192"/>
# <a class="category" href="/search/sna?query=bike%20rack&amp;sort=rel">atvs, utvs, snowmobiles</a> <span class="count">3</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="wta" id="cat_wta" name="cat_id" type="checkbox" value="203,204"/>
# <a class="category" href="/search/wta?query=bike%20rack&amp;sort=rel">auto wheels &amp; tires</a> <span class="count">3</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="ela" id="cat_ela" name="cat_id" type="checkbox" value="96,167"/>
# <a class="category" href="/search/ela?query=bike%20rack&amp;sort=rel">electronics</a> <span class="count">3</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="hva" id="cat_hva" name="cat_id" type="checkbox" value="193,194"/>
# <a class="category" href="/search/hva?query=bike%20rack&amp;sort=rel">heavy equipment</a> <span class="count">3</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="hsa" id="cat_hsa" name="cat_id" type="checkbox" value="97,181"/>
# <a class="category" href="/search/hsa?query=bike%20rack&amp;sort=rel">household items</a> <span class="count">3</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="bar" id="cat_bar" name="cat_id" type="checkbox" value="42"/>
# <a class="category" href="/search/bar?query=bike%20rack&amp;sort=rel">barter</a> <span class="count">1</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="bpa" id="cat_bpa" name="cat_id" type="checkbox" value="201,202"/>
# <a class="category" href="/search/bpa?query=bike%20rack&amp;sort=rel">boat parts &amp; accessories</a> <span class="count">1</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="cba" id="cat_cba" name="cat_id" type="checkbox" value="95,177"/>
# <a class="category" href="/search/cba?query=bike%20rack&amp;sort=rel">collectibles</a> <span class="count">1</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="zip" id="cat_zip" name="cat_id" type="checkbox" value="101"/>
# <a class="category" href="/search/zip?query=bike%20rack&amp;sort=rel">free stuff</a> <span class="count">1</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="ppa" id="cat_ppa" name="cat_id" type="checkbox" value="149,162"/>
# <a class="category" href="/search/ppa?query=bike%20rack&amp;sort=rel">appliances</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="ara" id="cat_ara" name="cat_id" type="checkbox" value="135,170"/>
# <a class="category" href="/search/ara?query=bike%20rack&amp;sort=rel">arts &amp; crafts</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="ava" id="cat_ava" name="cat_id" type="checkbox" value="208,209"/>
# <a class="category" href="/search/ava?query=bike%20rack&amp;sort=rel">aviation</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="boo" id="cat_boo" name="cat_id" type="checkbox" value="119,164"/>
# <a class="category" href="/search/boo?query=bike%20rack&amp;sort=rel">boats</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="bka" id="cat_bka" name="cat_id" type="checkbox" value="92,173"/>
# <a class="category" href="/search/bka?query=bike%20rack&amp;sort=rel">books &amp; magazines</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="ema" id="cat_ema" name="cat_id" type="checkbox" value="117,175"/>
# <a class="category" href="/search/ema?query=bike%20rack&amp;sort=rel">cds / dvds / vhs</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="moa" id="cat_moa" name="cat_id" type="checkbox" value="153,165"/>
# <a class="category" href="/search/moa?query=bike%20rack&amp;sort=rel">cell phones</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="cla" id="cat_cla" name="cat_id" type="checkbox" value="94,176"/>
# <a class="category" href="/search/cla?query=bike%20rack&amp;sort=rel">clothing &amp; accessories</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="syp" id="cat_syp" name="cat_id" type="checkbox" value="199,200"/>
# <a class="category" href="/search/syp?query=bike%20rack&amp;sort=rel">computer parts</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="sya" id="cat_sya" name="cat_id" type="checkbox" value="7,166"/>
# <a class="category" href="/search/sya?query=bike%20rack&amp;sort=rel">computers</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="gra" id="cat_gra" name="cat_id" type="checkbox" value="133,178"/>
# <a class="category" href="/search/gra?query=bike%20rack&amp;sort=rel">farm &amp; garden</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="haa" id="cat_haa" name="cat_id" type="checkbox" value="152,180"/>
# <a class="category" href="/search/haa?query=bike%20rack&amp;sort=rel">health and beauty</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="jwa" id="cat_jwa" name="cat_id" type="checkbox" value="120,182"/>
# <a class="category" href="/search/jwa?query=bike%20rack&amp;sort=rel">jewelry</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="maa" id="cat_maa" name="cat_id" type="checkbox" value="136,183"/>
# <a class="category" href="/search/maa?query=bike%20rack&amp;sort=rel">materials</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="msa" id="cat_msa" name="cat_id" type="checkbox" value="98,184"/>
# <a class="category" href="/search/msa?query=bike%20rack&amp;sort=rel">musical instruments</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="pha" id="cat_pha" name="cat_id" type="checkbox" value="137,185"/>
# <a class="category" href="/search/pha?query=bike%20rack&amp;sort=rel">photo/video</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="tia" id="cat_tia" name="cat_id" type="checkbox" value="44,161"/>
# <a class="category" href="/search/tia?query=bike%20rack&amp;sort=rel">tickets</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="tla" id="cat_tla" name="cat_id" type="checkbox" value="118,187"/>
# <a class="category" href="/search/tla?query=bike%20rack&amp;sort=rel">tools</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="taa" id="cat_taa" name="cat_id" type="checkbox" value="132,188"/>
# <a class="category" href="/search/taa?query=bike%20rack&amp;sort=rel">toys &amp; games</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="vga" id="cat_vga" name="cat_id" type="checkbox" value="151,189"/>
# <a class="category" href="/search/vga?query=bike%20rack&amp;sort=rel">video gaming</a> <span class="count">0</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="waa" id="cat_waa" name="cat_id" type="checkbox" value="20,190"/>
# <a class="category" href="/search/waa?query=bike%20rack&amp;sort=rel">wanted</a> <span class="count">0</span>
# </li>
# </ul>
# <div class="selectall js-only checked"><label>
# <input checked="checked" class="catcheck selectallcb" type="checkbox"/>
# <span class="all linklike">select all</span>
# </label></div>
# </div>
# <input name="userid" type="hidden" value="">
# <ul class="searchgroup buttongroup purveyor">
# <li class="button sel">
# <a data-val="all" href="/search/sss?query=bike%20rack&amp;sort=rel">all</a>
# </li><li class="button ">
# <a data-val="owner" href="/search/sso?query=bike%20rack&amp;sort=rel"> owner</a>
# </li><li class="button ">
# <a data-val="dealer" href="/search/ssq?query=bike%20rack&amp;sort=rel">dealer</a>
# </li>
# </ul>
# <div class="searchgroup">
# <ul>
# <li>
# <label class="srchType">
# <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#        </label>
# </li>
# <li>
# <label class="hasPic">
# <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#        </label>
# </li>
# <li>
# <label class="postedToday">
# <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#        </label>
# </li>
# <li>
# <label class="bundleDuplicates">
# <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#        </label>
# </li>
# <li>
# <label class="searchNearby">
# <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            include nearby areas
#        </label>
# </li>
# </ul>
# <ul class="js-only nearbyAreas ">
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_17" name="nearbyArea" type="checkbox" value="63">
#                             bakersfield, CA <small>(bak)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="187">
#                             chico, CA <small>(chc)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="43">
#                             fresno / madera <small>(fre)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="373">
#                             gold country <small>(gld)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="709">
#                             hanford-corcoran <small>(hnf)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="189">
#                             humboldt county <small>(hmb)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="454">
#                             mendocino county <small>(mdo)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="285">
#                             merced, CA <small>(mer)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="96">
#                             modesto, CA <small>(mod)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="102">
#                             monterey bay <small>(mtb)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="188">
#                             redding, CA <small>(rdd)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_13" name="nearbyArea" type="checkbox" value="92">
#                             reno / tahoe <small>(rno)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="12">
#                             sacramento <small>(sac)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="191">
#                             san luis obispo <small>(slo)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="62">
#                             santa barbara <small>(sba)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_14" name="nearbyArea" type="checkbox" value="710">
#                             santa maria, CA <small>(smx)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="708">
#                             siskiyou county <small>(ssk)</small>
# </input></label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="97">
#                             stockton, CA <small>(stk)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="707">
#                             susanville, CA <small>(ssn)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="208">
#                             ventura county <small>(oxr)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="346">
#                             visalia-tulare <small>(vis)</small>
# </input></label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="456">
#                             yuba-sutter, CA <small>(ybs)</small>
# </input></label>
# </li>
# <li>
# <span class="nextNearbyZone linklike" data-zone="1">
#                             + show <span id="nearbyNumber">22</span> more...
#                         </span>
# </li>
# </ul>
# </div>
# <div class="searchgroup">
# <span class="searchfieldlabel">miles from zip</span>
# <input class="flatinput searchInput search_distance" inputmode="numeric" max="200" min="0" name="search_distance" placeholder="miles" size="3" type="number" value="">
# <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
# <span class="icon icon-locate"></span>
# </input></div>
# <div class="searchgroup minmax price">
# <span class="searchfieldlabel">price</span>
# <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
# <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
# </div>
# <div class="searchgroup"><span class="searchfieldlabel">make and model</span>
# <input class="flatinput auto_make_model" data-autocomplete="makemodel" name="auto_make_model" placeholder="make / model" type="text" value="">
# </input></div><div class="searchgroup"> <div class="minmax engine_displacement_cc">
# <span class="searchfieldlabel">engine displacement (CC)</span>
# <input class="flatinput min" name="min_engine_displacement_cc" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
# <input class="flatinput max" name="max_engine_displacement_cc" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
# </div>
# <div class="minmax auto_year">
# <span class="searchfieldlabel">model year</span>
# <input class="flatinput min" name="min_auto_year" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
# <input class="flatinput max" name="max_auto_year" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
# </div>
# <div class="minmax auto_miles">
# <span class="searchfieldlabel">odometer</span>
# <input class="flatinput min" name="min_auto_miles" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
# <input class="flatinput max" name="max_auto_miles" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
# </div>
# </div><div class="searchgroup"><label class="crypto_currency_ok">
# <input class="autosubmit" name="crypto_currency_ok" type="checkbox" value="1">
#     cryptocurrency ok
# </input></label><br/>
# </div><div class="searchgroup"><div class="search-attribute hide-list" data-attr="bicycle_type">
# <div class="title linklike ">
# <span class="plus">▸</span><span class="minus">▾</span> bicycle type
#     </div>
# <ul class="list">
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_1" name="bicycle_type" type="checkbox" value="1">
#                     bmx
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_2" name="bicycle_type" type="checkbox" value="2">
#                     cargo/pedicab
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_3" name="bicycle_type" type="checkbox" value="3">
#                     cruiser
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_4" name="bicycle_type" type="checkbox" value="4">
#                     cyclocross
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_5" name="bicycle_type" type="checkbox" value="5">
#                     folding
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_6" name="bicycle_type" type="checkbox" value="6">
#                     hybrid/comfort
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_7" name="bicycle_type" type="checkbox" value="7">
#                     kids
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_8" name="bicycle_type" type="checkbox" value="8">
#                     mountain
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_9" name="bicycle_type" type="checkbox" value="9">
#                     recumbent/trike
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_10" name="bicycle_type" type="checkbox" value="10">
#                     road
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_11" name="bicycle_type" type="checkbox" value="11">
#                     tandem
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_12" name="bicycle_type" type="checkbox" value="12">
#                     track
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_13" name="bicycle_type" type="checkbox" value="13">
#                     unicycle
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_type_14" name="bicycle_type" type="checkbox" value="14">
#                     other
#                 </input></label>
# </li>
# <li class="selectall js-only ">
# <span class="all">select all</span>
# <span class="none">deselect all</span>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="bicycle_wheel_size">
# <div class="title linklike ">
# <span class="plus">▸</span><span class="minus">▾</span> wheel size
#     </div>
# <ul class="list">
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_1" name="bicycle_wheel_size" type="checkbox" value="1">
#                     10 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_2" name="bicycle_wheel_size" type="checkbox" value="2">
#                     12 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_3" name="bicycle_wheel_size" type="checkbox" value="3">
#                     14 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_4" name="bicycle_wheel_size" type="checkbox" value="4">
#                     16 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_5" name="bicycle_wheel_size" type="checkbox" value="5">
#                     18 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_6" name="bicycle_wheel_size" type="checkbox" value="6">
#                     20 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_7" name="bicycle_wheel_size" type="checkbox" value="7">
#                     24 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_8" name="bicycle_wheel_size" type="checkbox" value="8">
#                     25 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_9" name="bicycle_wheel_size" type="checkbox" value="9">
#                     26 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_10" name="bicycle_wheel_size" type="checkbox" value="10">
#                     26.5 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_11" name="bicycle_wheel_size" type="checkbox" value="11">
#                     27 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_12" name="bicycle_wheel_size" type="checkbox" value="12">
#                     27.5 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_13" name="bicycle_wheel_size" type="checkbox" value="13">
#                     28 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_14" name="bicycle_wheel_size" type="checkbox" value="14">
#                     29 in
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_15" name="bicycle_wheel_size" type="checkbox" value="15">
#                     650B
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_16" name="bicycle_wheel_size" type="checkbox" value="16">
#                     650C
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_17" name="bicycle_wheel_size" type="checkbox" value="17">
#                     700C
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_wheel_size_18" name="bicycle_wheel_size" type="checkbox" value="18">
#                     other/unknown
#                 </input></label>
# </li>
# <li class="selectall js-only ">
# <span class="all">select all</span>
# <span class="none">deselect all</span>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="bicycle_suspension">
# <div class="title linklike ">
# <span class="plus">▸</span><span class="minus">▾</span> suspension
#     </div>
# <ul class="list">
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_suspension_1" name="bicycle_suspension" type="checkbox" value="1">
#                     none (rigid)
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_suspension_2" name="bicycle_suspension" type="checkbox" value="2">
#                     suspension fork (hardtail)
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_suspension_3" name="bicycle_suspension" type="checkbox" value="3">
#                     frame and fork (full suspension)
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_suspension_4" name="bicycle_suspension" type="checkbox" value="4">
#                     other/unknown
#                 </input></label>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="bicycle_brake_type">
# <div class="title linklike ">
# <span class="plus">▸</span><span class="minus">▾</span> brake type
#     </div>
# <ul class="list">
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_1" name="bicycle_brake_type" type="checkbox" value="1">
#                     caliper
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_2" name="bicycle_brake_type" type="checkbox" value="2">
#                     cantilever
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_3" name="bicycle_brake_type" type="checkbox" value="3">
#                     coaster
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_4" name="bicycle_brake_type" type="checkbox" value="4">
#                     disc (hydraulic)
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_5" name="bicycle_brake_type" type="checkbox" value="5">
#                     disc (mechanical)
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_6" name="bicycle_brake_type" type="checkbox" value="6">
#                     drum
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_7" name="bicycle_brake_type" type="checkbox" value="7">
#                     gyro/bmx
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_8" name="bicycle_brake_type" type="checkbox" value="8">
#                     hydraulic rim brakes
#                 </input></label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_9" name="bicycle_brake_type" type="checkbox" value="9"/>
#                     none
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_10" name="bicycle_brake_type" type="checkbox" value="10"/>
#                     u-brakes
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_11" name="bicycle_brake_type" type="checkbox" value="11"/>
#                     v-brakes
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_brake_type_12" name="bicycle_brake_type" type="checkbox" value="12"/>
#                     other/unknown
#                 </label>
# </li>
# <li class="selectall js-only ">
# <span class="all">select all</span>
# <span class="none">deselect all</span>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="bicycle_handlebar_type">
# <div class="title linklike ">
# <span class="plus">▸</span><span class="minus">▾</span> handlebar type
#     </div>
# <ul class="list">
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_handlebar_type_1" name="bicycle_handlebar_type" type="checkbox" value="1"/>
#                     aero
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_handlebar_type_2" name="bicycle_handlebar_type" type="checkbox" value="2"/>
#                     bmx
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_handlebar_type_3" name="bicycle_handlebar_type" type="checkbox" value="3"/>
#                     bullhorn
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_handlebar_type_4" name="bicycle_handlebar_type" type="checkbox" value="4"/>
#                     cruiser
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_handlebar_type_5" name="bicycle_handlebar_type" type="checkbox" value="5"/>
#                     downhill
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_handlebar_type_6" name="bicycle_handlebar_type" type="checkbox" value="6"/>
#                     drop
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_handlebar_type_7" name="bicycle_handlebar_type" type="checkbox" value="7"/>
#                     flat
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_handlebar_type_8" name="bicycle_handlebar_type" type="checkbox" value="8"/>
#                     riser
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_handlebar_type_9" name="bicycle_handlebar_type" type="checkbox" value="9"/>
#                     triathlon
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_handlebar_type_10" name="bicycle_handlebar_type" type="checkbox" value="10"/>
#                     other/unknown
#                 </label>
# </li>
# <li class="selectall js-only ">
# <span class="all">select all</span>
# <span class="none">deselect all</span>
# </li>
# </ul>
# </div>
# <div class="search-attribute hide-list" data-attr="bicycle_electric_assist">
# <div class="title linklike ">
# <span class="plus">▸</span><span class="minus">▾</span> electric assist
#     </div>
# <ul class="list">
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_electric_assist_1" name="bicycle_electric_assist" type="checkbox" value="1"/>
#                     none
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_electric_assist_2" name="bicycle_electric_assist" type="checkbox" value="2"/>
#                     pedal assist
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="bicycle_electric_assist_3" name="bicycle_electric_assist" type="checkbox" value="3"/>
#                     throttle
#                 </label>
# </li>
# ...
# <span class="result-hood"> (milpitas)</span>
# <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6831540433">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6831528982" data-repost-of="6745614821">
# <a class="result-image gallery" data-ids="1:00g0g_ludIvkddqPC,1:00q0q_3uo5lvOLZRM" href="https://sfbay.craigslist.org/sfc/spo/d/san-francisco-yakima-trunk-mount-bike/6831528982.html">
# <span class="result-price">$30</span>
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-03-01 21:22" title="Fri 01 Mar 09:22:54 PM">Mar  1</time>
# <a class="result-title hdrlnk" data-id="6831528982" href="https://sfbay.craigslist.org/sfc/spo/d/san-francisco-yakima-trunk-mount-bike/6831528982.html">Yakima trunk mount bike rack</a>
# <span class="result-meta">
# <span class="result-price">$30</span>
# <span class="result-hood"> (lower haight)</span>
# <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6831528982">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6831514076">
# <a class="result-image gallery" data-ids="1:00T0T_7eEfMHn4MDw" href="https://sfbay.craigslist.org/eby/bik/d/albany-floor-to-ceiling-bike-rack/6831514076.html">
# <span class="result-price">$50</span>
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-03-01 20:31" title="Fri 01 Mar 08:31:20 PM">Mar  1</time>
# <a class="result-title hdrlnk" data-id="6831514076" href="https://sfbay.craigslist.org/eby/bik/d/albany-floor-to-ceiling-bike-rack/6831514076.html">Floor to Ceiling Bike Rack</a>
# <span class="result-meta">
# <span class="result-price">$50</span>
# <span class="result-hood"> (albany / el cerrito)</span>
# <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6831514076">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6813717040" data-repost-of="6732920033">
# <a class="result-image gallery" data-ids="1:01313_j6qXd7bfDH8,1:00u0u_50wcvgV6CGC" href="https://sfbay.craigslist.org/nby/spo/d/sebastopol-2-bike-rack-hitch-mount-by/6813717040.html">
# <span class="result-price">$65</span>
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-03-01 20:27" title="Fri 01 Mar 08:27:57 PM">Mar  1</time>
# <a class="result-title hdrlnk" data-id="6813717040" href="https://sfbay.craigslist.org/nby/spo/d/sebastopol-2-bike-rack-hitch-mount-by/6813717040.html">2 Bike Rack Hitch Mount by Subaru</a>
# <span class="result-meta">
# <span class="result-price">$65</span>
# <span class="result-hood"> (sebastopol)</span>
# <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6813717040">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6826133644" data-repost-of="6804724797">
# <a class="result-image gallery" data-ids="1:00W0W_elsE05LXVDq,1:00D0D_eI4yokT8VdG" href="https://sfbay.craigslist.org/sby/bop/d/milpitas-bell-bike-rack/6826133644.html">
# <span class="result-price">$25</span>
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-03-01 19:37" title="Fri 01 Mar 07:37:05 PM">Mar  1</time>
# <a class="result-title hdrlnk" data-id="6826133644" href="https://sfbay.craigslist.org/sby/bop/d/milpitas-bell-bike-rack/6826133644.html">Bell Bike Rack</a>
# <span class="result-meta">
# <span class="result-price">$25</span>
# <span class="result-hood"> (milpitas)</span>
# <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6826133644">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6828248531" data-repost-of="6679826018">
# <a class="result-image gallery" data-ids="1:01515_8IB5AMyOMIu,1:00F0F_11FmuiTsYG0" href="https://sfbay.craigslist.org/sfc/bik/d/san-francisco-bike-rack/6828248531.html">
# <span class="result-price">$30</span>
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-03-01 19:17" title="Fri 01 Mar 07:17:12 PM">Mar  1</time>
# <a class="result-title hdrlnk" data-id="6828248531" href="https://sfbay.craigslist.org/sfc/bik/d/san-francisco-bike-rack/6828248531.html">BIKE RACK</a>
# <span class="result-meta">
# <span class="result-price">$30</span>
# <span class="result-hood"> (sunset / parkside)</span>
# <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6828248531">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6829083158" data-repost-of="4896251914">
# <a class="result-image gallery" data-ids="1:00z0z_lnbN2qaQlNA,1:00k0k_3KgozNkLeSf,1:00606_4BQsUI91Sip,1:01010_kWSfFQDDVAj" href="https://sfbay.craigslist.org/eby/bik/d/bike-bicycle-carrier-rack-rhino-rbc017/6829083158.html">
# <span class="result-price">$105</span>
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-03-01 19:00" title="Fri 01 Mar 07:00:12 PM">Mar  1</time>
# <a class="result-title hdrlnk" data-id="6829083158" href="https://sfbay.craigslist.org/eby/bik/d/bike-bicycle-carrier-rack-rhino-rbc017/6829083158.html">Bike Bicycle Carrier Rack Rhino RBC017</a>
# <span class="result-meta">
# <span class="result-price">$105</span>
# <span class="result-hood"> (pittsburg / antioch)</span>
# <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6829083158">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# </ul>
# </div>
# <div class="search-legend bottom">
# <div class="search-view">
# <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
# </div>
# <div class="search-sort">
# <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
# </div>
# <div class="paginator buttongroup firstpage">
# <span class="resulttotal">
# <span class="for-map">
#         displaying <span class="displaycountShow">...</span> postings
#         </span>
# </span>
# <span class="buttons">
# <a class="button first" href="/search/sss?query=bike%20rack&amp;sort=rel" title="first page">&lt;&lt;</a>
# <span class="button first" title="first page">&lt;&lt;</span>
# <a class="button prev" href="/search/sss?query=bike%20rack&amp;sort=rel" title="previous page">&lt; prev</a>
# <span class="button prev" title="previous page">&lt; prev</span>
# <span class="button pagenum">
# <span class="range">
# <span class="rangeFrom">1</span>
#                 -
#                 <span class="rangeTo">120</span>
# </span>
#             /
#             <span class="totalcount">1282</span>
# </span>
# <a class="button next" href="/search/sss?s=120&amp;query=bike%20rack&amp;sort=rel" title="next page">next &gt; </a>
# <span class="button next" title="next page"> next &gt; </span>
# </span>
# </div>
# </div>
# <section class="blurbs">
# </section>
# <div id="floater">
# <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
# <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
# </div>
# </form>
# <aside class="tsb">
# <ul>
# <li><a href="https://www.craigslist.org/about/safety">safety tips</a>
# <li><a href="https://www.craigslist.org/about/prohibited">prohibited items</a>
# <li><a href="https://www.craigslist.org/about/recalled_items">product recalls</a>
# <li><a href="https://www.craigslist.org/about/scams">avoiding scams</a>
# </li></li></li></li></ul>
# </aside>
# <div class="slidemessage">
# <span class="fave">
# <span class="star"></span>
#         favorited
#     </span>
# <span class="unfave">
# <span class="star"></span>
#         no longer favorited
#     </span>
# <span class="hide">
# <span class="trash"></span>
#         hidden
#     </span>
# <span class="unhide">
# <span class="trash"></span>
#         no longer hidden
#     </span>
# </div>
# <footer>
# <span class="rss">
# <a class="l" href="https://sfbay.craigslist.org/search/sss?format=rss&amp;query=bike%20rack&amp;sort=rel">RSS</a>
# <a href="https://www.craigslist.org/about/rss">(?)</a><br/>
# </span>
# <ul class="clfooter">
# <li>©  <span class="desktop">craigslist</span><span class="mobile">CL</span></li>
# <li><a href="https://www.craigslist.org/about/help/">help</a></li>
# <li><a href="https://www.craigslist.org/about/scams">safety</a></li>
# <li class="desktop"><a href="https://www.craigslist.org/about/privacy.policy">privacy</a></li>
# <li class="desktop"><a href="https://forums.craigslist.org/?forumID=8">feedback</a></li>
# <li class="desktop"><a href="https://www.craigslist.org/about/craigslist_is_hiring">cl jobs</a></li>
# <li><a href="//www.craigslist.org/about/terms.of.use.en-us">terms</a><sup class="neu">new</sup></li>
# <li><a href="https://www.craigslist.org/about/">about</a></li>
# <li class="fsel desktop linklike" data-mode="mobile">mobile</li>
# <li class="fsel mobile linklike" data-mode="regular">desktop</li>
# </ul>
# </footer>
# </section>
# <template id="gallerycarousel">
# <div class="slider-info"></div><div class="slider-back arrow">&lt;</div><div class="slider-forward arrow">&gt;</div>
# </template>
# <script src="//www.craigslist.org/js/general-concat.min.js?v=ec2809ab798c64f11701752083535431" type="text/javascript"></script>
# <script type="text/javascript"><!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     --></script>
# <script id="clustertemplate" type="text/template">
#     <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
# </script>
# <script id="postingtemplate" type="text/template">
#     <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
# </script>
# <script id="popuptemplate" type="text/template">
#     <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
# </script>
# <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=b4f9b48fd7339d4a19e71c500faae0cb" type="text/javascript"></script>
# <script src="//www.craigslist.org/js/search-concat.min.js?v=5e86cef40294fd055513088f954de803" type="text/javascript"></script>
# <script src="//www.craigslist.org/js/postings-concat.min.js?v=33044b660200679fcccbf86838189c88" type="text/javascript"></script>
# </body>
# </html>

# %%
from bs4 import BeautifulSoup as bs
import requests
import os
url ='https://www.reddit.com/r/Python/'
filepath = os.path.join("Programmer-Humor.html")
with open(filepath,encoding="utf-8") as file:
    html = file.read()
soup =BeautifulSoup(html, 'html.parse')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-b168218f343a> in <module>()
#       4 url ='https://www.reddit.com/r/Python/'
#       5 filepath = os.path.join("Programmer-Humor.html")
# ----> 6 with open(filepath,encoding="utf-8") as file:
#       7     html = file.read()
#       8 soup =BeautifulSoup(html, 'html.parse')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Programmer-Humor.html'

# %%
import pandas as pd
url ='https://en.wikipedia.org/wiki/List_of_capitals_in_the_United_States'
tables = pd.read_html(url)
df=tables[2]
df.head()
# Out:
#                               0                                            1  \
# 0                         State                                      Capital
# 1  Alabama[14]Statehood in 1819                                  San Agustín
# 2                      Savannah                                         1733
# 3                          1755  Capital of the British Province of Georgia.
# 4                          1776            Capitals of the State of Georgia.
#
#                                                    2  \
# 0                                               Date
# 1                                               1565
# 2  Capital of the British proprietary Colony of G...
# 3                                                NaN
# 4                                                NaN
#
#                                                   3
# 0                                             Notes
# 1  Capital of the Spanish colony of La Florida.[15]
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
